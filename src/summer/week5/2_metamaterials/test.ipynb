# %%
print("BHJ")
# Out:
# BHJ

# %%
import os

node_list = os.environ.get("SLURM_NODELIST")
print(f"Current Slurm node allocation: {node_list}")

import platform

print(platform.python_version())
# Out:
# Current Slurm node allocation: None
# 3.13.14
