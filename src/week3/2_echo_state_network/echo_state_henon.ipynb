# %%
import numpy as np

import plotly.graph_objects as go

# %%
steps = 20000

transient_steps_henon = int(steps * 0.1)
transient_steps_reservoir = int(steps * 0.1)
total_steps = steps + transient_steps_henon + transient_steps_reservoir

test_size = 0.2

t = np.arange(0, total_steps)

# %% [markdown]
# # Init

# %%
henon_dataset = np.zeros((total_steps, 2))

rng = np.random.default_rng(42)
henon_dataset[0] = rng.random(2)

a = 1.4
b = .3

# %%
@njit
def henon_numba(steps, x0=0.0, y0=0.0, a=1.4, b=0.3):
    X = np.zeros(steps)
    Y = np.zeros(steps)
    X[0] = x0
    Y[0] = y0

    for i in range(1, steps):
        X[i] = 1 - a * X[i - 1] ** 2 + Y[i - 1]
        Y[i] = b * X[i - 1]

    return X, Y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 @njit
#       2 def henon_numba(steps, x0=0.0, y0=0.0, a=1.4, b=0.3):
#       3     X = np.zeros(steps)
#       4     Y = np.zeros(steps)
#
# NameError: name 'njit' is not defined

# %%
henon_data_x, henon_data_y = henon_numba(total_steps)

henon_dataset = np.column_stack((henon_data_x, henon_data_y))
henon_dataset = henon_dataset[transient_steps_henon:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 henon_data_x, henon_data_y = henon_numba(total_steps)
#       2
#       3 henon_dataset = np.column_stack((henon_data_x, henon_data_y))
#       4 henon_dataset = henon_dataset[transient_steps_henon:]
#
# NameError: name 'henon_numba' is not defined

# %%
def henon_plot(data):
    fig = go.Figure(
        data=go.Scatter(
            x=data[:, 0],
            y=data[:, 1],
            mode="markers",
            marker=dict(color="white", size=1)
        )
    )
    
    fig.update_layout(
        plot_bgcolor="black",
        paper_bgcolor="black",
        font=dict(color="white"),
        
        xaxis=dict(
            showgrid=False, 
            zeroline=False, 
            linecolor="white",
            ticks="outside",
            tickcolor="white"
        ),
        yaxis=dict(
            showgrid=False,
            zeroline=False,
            linecolor="white",
            ticks="outside",
            tickcolor="white"
        )
    )
    
    return fig

# %%
fig = henon_plot(henon_dataset)
fig.show()
