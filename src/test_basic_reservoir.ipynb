# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 100, 2000)
data = np.sin(t)

# %%
plt.plot(t, data, "o")

# %%
train_len = 1000
test_len = 500

# %%
# Let's do var as an example for now
res_size = 100 # How much dimensionality the sim will have kinda
